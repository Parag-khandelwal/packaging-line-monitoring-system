# %%
import sys
sys.path.append("C:\\Users\\Dell\\OneDrive\\Desktop\\predictive-maintenance-ai4i")

# %%
from scripts.evaluate import evaluate_model
from scripts.preprocess import load_and_preprocess_data
import joblib

# %%
model = joblib.load("../models/random_forest.pkl")
X_train, X_test, y_train, y_test = load_and_preprocess_data("../data/ai4i2020.csv")

y_pred = model.predict(X_test)

# %%
evaluate_model(y_test, y_pred)
# Out:
# Accuracy: 0.9825
